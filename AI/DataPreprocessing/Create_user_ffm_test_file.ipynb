# %%
import pandas as pd
import numpy as np
import os
from sklearn.preprocessing import LabelEncoder
import joblib
import ast

data_path = '../DataSet/'
lib_path = '../Dataset/lib_dataset/'
encoder_data_path = '../DataSet/Encoder/'

user_df = pd.read_csv(os.path.join(data_path, 'final_Baekjoon_유저_크롤링.csv'))
problem_df = pd.read_csv(os.path.join(data_path, 'final_Baekjoon_문제_크롤링.csv'))
lib_df = pd.read_csv(os.path.join(lib_path, 'Non_Encoding_lib_data.csv'))

user_ID_Encoder = joblib.load(os.path.join(encoder_data_path, 'user_ID_Encoder.joblib'))
problem_number_Encoder = joblib.load(os.path.join(encoder_data_path, 'problem_number_Encoder.joblib'))
problem_algorithm_Encoder = joblib.load(os.path.join(encoder_data_path, 'problem_algorithm_Encoder.joblib'))

# %%
list(user_df['user_id'].unique())
# Out:
# ['teddybear1024',
#  'vladimir11',
#  'minkim3987',
#  'movie_jo',
#  'mymasterpark2',
#  'paengjiwon',
#  'sedev57',
#  '110000110101',
#  'kdk',
#  'repelit',
#  'crypt9',
#  'dnlsehdn9779',
#  'kkpos0206',
#  'wjshim',
#  'youngjun7',
#  'ajdxjdrnfl',
#  'songuno1',
#  'vega',
#  'dnialh',
#  'akswnd98',
#  'cooki0615',
#  'tjdgus4384',
#  'jjmjm2002',
#  'khcho0125',
#  'tykr0001',
#  'Apple_Cplus',
#  'huisung0205',
#  'solibaht',
#  'mooni',
#  'onteeae',
#  'louisdebroglie',
#  'rasauq1122',
#  'cptech',
#  'wlgur1023',
#  'cocoa_chan',
#  'impri',
#  'gs16109',
#  'poketred12',
#  'roeyr',
#  'jkuk5046',
#  'sr3gm',
#  'jpseo99',
#  'mingyu331',
#  'RiKang',
#  'wonkyum256',
#  'malratz',
#  'sky0331',
#  'amok',
#  'buttercrab',
#  'kangwlgns',
#  'paul3143',
#  'shortcakesweets',
#  'fbdp1202',
#  'ghdcks33',
#  'holonomic0401',
#  'martin0327',
#  'mj1000j',
#  'seurametum',
#  'tlsgkdns',
#  'raikoin',
#  'minsiwon00',
#  'o9j8w7',
#  'rootcucu',
#  'yeolyii',
#  'akwkek11',
#  'p_jun',
#  'rbtmd1010',
#  'yous',
#  'bongssi',
#  'wrath9764',
#  'dlaud5379',
#  'henryx',
#  'ilove209b',
#  'kgw0103',
#  'moon960323',
#  'openingsound',
#  'wjdrkrwnd',
#  'bsheep0304',
#  'holmane333',
#  'mbae059',
#  'gw0419',
#  'qwebnm7788',
#  'ki9014',
#  'koko514',
#  'ydk1104',
#  '0203peter',
#  'ahmg1216',
#  'cbs0615',
#  'hxgn0221',
#  'jinjh0707',
#  'ls4154',
#  'sayingduck',
#  'ygonepiece',
#  'juhan',
#  'ljwljw8541',
#  'pillarpond',
#  'rkdxowhd98',
#  'sunho',
#  'applied7076',
#  'coffeetea',
#  'dbrua1222',
#  'QuqqU',
#  'qvixnh22',
#  'yangpyeong',
#  'dohyonne',
#  'ds4ouj',
#  'hu8232',
#  'lys9546',
#  'sd12339',
#  'starwarscks',
#  '2468ab',
#  'cdt416z',
#  'duram21',
#  'ispark',
#  'joynet',
#  'meaculpa9450',
#  'tat1218',
#  'jaejin0209',
#  'junhyeog',
#  'jatana',
#  'seonah',
#  'skdudn321',
#  'wjh5597486',
#  'qdjjd',
#  'skyde47',
#  '20210805',
#  'david0506',
#  'qkrlwsnd',
#  'kimcoding',
#  'mekind',
#  'mnx',
#  'Rose',
#  'dbgusdn012',
#  'dbtmdgns4296',
#  'dhdroid',
#  'kan5995',
#  'lim551',
#  'reunai',
#  'ujoon',
#  'bunker12383',
#  'kkw564',
#  'mario34',
#  'qwer9412',
#  'wwiiiii',
#  'grands',
#  'zhxpdustmqdyd',
#  'asdfghjkl46',
#  'namhong2001',
#  'scalefreeus',
#  'nukec',
#  'akwk777',
#  'ness9917',
#  'csehydrogen',
#  'saycorn',
#  'shinm0819',
#  'shyram',
#  'wogudwkd12',
#  'yumk0717',
#  'kjykju7457',
#  'lulunlnl',
#  'cloyster',
#  'inksamurai',
#  'minggyul',
#  'pdw0412',
#  'kij0909',
#  'checkpt',
#  'dlstj0923',
#  'doraemon0903',
#  'lapi5',
#  'nflight11',
#  'hjhj97',
#  'jangzzang',
#  'q540jh',
#  'solo5star',
#  'anbj1004',
#  'gktgnjftm',
#  'l1ardanc3',
#  'minchae2930',
#  'ababc1005',
#  'bcc0830',
#  'plzrun',
#  'sys0927',
#  'hana5505',
#  'reniowood',
#  'sinphi01',
#  'tmdrud0',
#  'ian0704',
#  'kind2783',
#  'namil208',
#  'noahdy967',
#  'dlfgh159',
#  'juyoung35',
#  'linak',
#  'pwj6800',
#  'skipp1223',
#  'isku',
#  'jeongdongha',
#  'klm03025',
#  '314programs',
#  'drcotr0623',
#  'mani828',
#  'realbe',
#  'wts1597',
#  'alohajm',
#  'myeongbo123',
#  'protalk',
#  'darkdulgi',
#  'eovh1962',
#  'sth3353',
#  'tizm423',
#  'chams09',
#  'dreamw',
#  'js1044k',
#  'gnzpstly2000',
#  'iktk',
#  'juneharold',
#  'sohnryang',
#  'tjsh0111',
#  'jdj1211',
#  'koreii',
#  'tndyd0706',
#  'youx',
#  'armyantking',
#  'hadudwo0409',
#  'jung2381187',
#  'kimh060612',
#  'swiftruby0921',
#  'mon_de2738',
#  '1000sxbh',
#  'dlwodnsdl',
#  'b643100',
#  'blueapple99',
#  'hzw94',
#  'shwldus067',
#  'zerowest1001',
#  'harold0879',
#  'ik_e',
#  'kimmingee2008',
#  'pgggggggggh',
#  'hithere314',
#  'kdk8361',
#  'kyh298494',
#  'surung9898',
#  'beddl',
#  'greenfox',
#  'eldpswp99',
#  'geniusjo16',
#  'junghyun33',
#  'pings',
#  'tlsgusrb314',
#  'wbjeon2k',
#  'g3gogogo',
#  'jaeyeong16',
#  'kss418',
#  'degurii',
#  'rhasya',
#  'wnsqlehlswk',
#  'lety',
#  'mwy3055',
#  'pica4500',
#  'tjdgnsqn3',
#  'drash99',
#  'ksi990302',
#  'smsm8111',
#  'yeongjava1997',
#  'dhlee1031',
#  'dwax1324',
#  'ivanperisic444',
#  'jrguyyoo',
#  'korking',
#  'ses9928',
#  'a_bcde',
#  'dlftls38',
#  'dpsqlsdh',
#  'ha_ram',
#  'heize',
#  'msjeong',
#  'swc0317',
#  'arcane22',
#  'hyunynim',
#  'juhongkim2',
#  'gravekper',
#  'rhsek123',
#  'ckdgus2482',
#  'layer6ai',
#  'soo28819',
#  'jh040597',
#  'limepencil',
#  'semteo02',
#  'sure97',
#  'wkd1685',
#  'bkwak',
#  'mathlife',
#  'woqja125',
#  'chun75',
#  'dmjhkim',
#  'sesang06',
#  'sksms1375',
#  'ghdic',
#  'jangkke',
#  'skeletonk',
#  'sweatpotato',
#  'tjfvmfdydid_java',
#  'yoonyesle',
#  'mic1021',
#  'q8514199',
#  'system_error_code_0',
#  'astro1126',
#  'inju2403',
#  'tapeclouds',
#  'erolf0123',
#  'htjung09',
#  'leehosu01',
#  'elemae6',
#  '0do',
#  '1bin',
#  'dbfldkfdbgml',
#  'keunbum',
#  'rhsehfm33',
#  'zjtlfk',
#  '16silver',
#  'cbkpar',
#  'dnj000920',
#  'upsk1',
#  'y103kim',
#  'daejjyu',
#  'ii_eugene_ii',
#  'kibbomi',
#  'psi0613',
#  'blou888',
#  'neogate',
#  '01089292615',
#  'babeeboo2000',
#  'cdg0228',
#  'stupy3on',
#  'young1023',
#  'ds030337',
#  'hasw7569',
#  'naong606',
#  'sjh1224',
#  'turgon314',
#  'leethyun',
#  'wie_eiw',
#  'y305205',
#  '0styycp',
#  'jake0713',
#  'oct301',
#  'partially_ai',
#  'sh0416',
#  'gangminson',
#  'pistack',
#  'qwe123rt45',
#  'chpark1111',
#  'gs21093',
#  'juhyun16',
#  'polygon',
#  'dotoleeoak',
#  'flareon078',
#  'thdtjdals3',
#  'uk7880',
#  'houma757',
#  '8624paul',
#  'bu_gye_jeong',
#  'cwd1',
#  'leeym95',
#  'smy4024169',
#  'vmffotltka',
#  'working05',
#  'asdfguest',
#  'BothEarRim',
#  'loes353',
#  'sangmin7b',
#  'tor012',
#  'wyldecat',
#  'bossusuprem',
#  'gcmango',
#  'tij03105',
#  'ddepddep',
#  'dhwjddn88',
#  'hyeon9456',
#  'kuy04195',
#  'tnpfldyd',
#  'dfwdf77',
#  'dongpang',
#  'hynb13',
#  'orgin00',
#  'pdm0205',
#  'statco19',
#  'zz79ya',
#  'gkgg123',
#  'itinbangk',
#  'wonrok97',
#  'hck5209',
#  'kkhmsg30',
#  'lighter',
#  'monch98',
#  'sjh931125',
#  'jmkk27',
#  'junek3',
#  'kerochuu',
#  'pipim468',
#  'elvpfhhrm',
#  'jhy213',
#  'pwr2011',
#  'seojaeam',
#  'sontg123',
#  'shoo040113',
#  'fastru',
#  'hwj8963',
#  'kritias',
#  'jerry9803',
#  'minjun13795',
#  'tothesky7',
#  'tyg03485',
#  'anonyk',
#  'lcr7324',
#  'mckingtori',
#  'huh0918',
#  'kokodak',
#  '99edward',
#  'bee980727',
#  'game2k',
#  'koqj123',
#  'cscsksks',
#  'oheat87',
#  'ysnam9041',
#  'cozpsh',
#  'fafnir',
#  'judge0001',
#  '4f3a87nm',
#  'checkchck',
#  'jihookang',
#  'shg9411',
#  'suhodnkla',
#  'ai4youej',
#  'airplane9876',
#  'ccwcs',
#  'csh4096',
#  'lee107601d',
#  'qhwhehwh',
#  'daniel604',
#  'dk040106',
#  'geon6757',
#  'mtso15',
#  'rrtrrt02',
#  'ficy',
#  'jinsoolve',
#  'jsh00325',
#  'minpago',
#  'qkrwndnjs',
#  'rkdalsdn7',
#  'tjwjdgjs22',
#  'hhs5125',
#  'jaegoomon',
#  'jseo',
#  'jongwook123',
#  'leekh2002',
#  'lsh000805',
#  'shhj1998',
#  'yajungi',
#  'yeahwhat11',
#  'bjwj5505',
#  'tph00300',
#  'crasy111',
#  'dkvmflzk98',
#  'dth04019',
#  'kimhy4480',
#  'lsh0426',
#  'tjdans6342',
#  'julysky',
#  'koder0205',
#  'lsh9034',
#  'sdpr',
#  'abcdefg',
#  'tjtkdgus45',
#  'uss425',
#  'yjwr0528',
#  'ace913',
#  'holenet',
#  'prixia',
#  'yooyou7',
#  'cmk5187',
#  'siwoo10804_a',
#  'sonamoo',
#  'justinwk',
#  'kimkh7534',
#  'ontael333',
#  'hschoi1104',
#  'patata22',
#  'gaelim',
#  'gauss148',
#  'firacode',
#  'junk06',
#  'kimgat16',
#  'setsuna',
#  'specidiee',
#  'dlbae9613',
#  'extra1563',
#  'go203302',
#  'jh280722',
#  'masooka',
#  'qverck',
#  'ramic',
#  'rudalsd',
#  'trytty',
#  'dlqudrjs',
#  'javago',
#  'lcy960729',
#  'miryu',
#  'dmj2004',
#  'jangjs1216',
#  'kpeel5839',
#  'per_ardua_ad_astra',
#  'gangtaeng',
#  'pepper_mis',
#  'thfdk0101',
#  'eric0417',
#  'jbh0224',
#  'ngchaneok',
#  'ngd',
#  'hazxz',
#  'pso5594',
#  'shareshate',
#  '0xchaser',
#  'junu22',
#  'lakshimi',
#  'woojin1204',
#  'loosie999',
#  'physics0523',
#  'compilers',
#  'kadrick',
#  'swdaniel',
#  'furthermares',
#  'ksh021144',
#  'na982',
#  'aaat',
#  'smj0328',
#  'tjtjdals',
#  'xkdlaldfjtnl',
#  'bae1776',
#  'chan120714',
#  'kmheaster',
#  'logwns',
#  'river_mseok',
#  'algo_itso',
#  'hmlv',
#  'i12345l',
#  'jb0830',
#  'ksi4495',
#  'whitehorse',
#  'kangkunma',
#  'dalcomi20',
#  'isbidip',
#  'sheenjiwon',
#  'tonyjjw',
#  'arron0513',
#  'insuhkim',
#  'kookmin20103324',
#  'an3735297',
#  'heyok',
#  'kimwujin1914',
#  'minpaper',
#  'ray5273',
#  'sestrik',
#  'busyhuman',
#  'dodobow',
#  'gmtmoney2357',
#  'wafter',
#  'duho1004',
#  'soma012',
#  'trailer',
#  'bsgreentea',
#  'leese0425',
#  'veckal',
#  'b5460881',
#  'franj',
#  'lgm9',
#  'orange4glace',
#  'cliid',
#  'define_chan',
#  'jak5022',
#  'joonseok_aaren_kang',
#  'maple19out',
#  'qls0860',
#  'whwoals21',
#  'zow777',
#  'cmk5432',
#  'midori',
#  'redrain',
#  'starbucks_americano',
#  'wclee2265',
#  'dongu0124',
#  'recoma',
#  'yongdori',
#  'codingstarfish',
#  'grantzile',
#  'rickmccoy',
#  'a1benjamin',
#  'bjk1649',
#  'cksgur1765',
#  'countywest',
#  'gudfhr95',
#  'kgstiger',
#  'kms9937',
#  'kws04004',
#  'sunghyeck17',
#  'euphoric_n',
#  'junhyung9985',
#  'pinomini',
#  'wxogus25',
#  'chatterboy',
#  'cieldinoegg',
#  'du9172',
#  'hg010303',
#  'jinsub1999',
#  'jjangguzi',
#  'mugil2005',
#  '113minecraft',
#  'fin',
#  'kangsw1025',
#  'oud3noida',
#  'woo960131',
#  'coglyi',
#  'mhkim4886',
#  'sewon1407',
#  'tk4003950',
#  'vegahouse102',
#  'wjddlsy',
#  'wvw',
#  'yukino',
#  'zxc9221',
#  'jeonyj1020',
#  'leehk_py',
#  'loveleesj',
#  'mixnuts',
#  'rhrnak',
#  'again7536',
#  'atrux',
#  'brighthonor',
#  'dladydwo123',
#  'jason79',
#  '83tachyon',
#  'cmw0107',
#  'promis9',
#  'yoonseokch',
#  'rlagusdnr120',
#  'smk5647',
#  'awdcgy',
#  'han811',
#  'hoxymola',
#  'hyunsu11',
#  'joseph8375',
#  'kong_22',
#  'linter',
#  'dslr',
#  'enthsxpzm',
#  '55murphy',
#  'k1671k',
#  'chlwnsgurb',
#  'dlcoguswkd',
#  'lio_oil7',
#  'pinebananais',
#  'tiranosm',
#  'yunobo',
#  'asdarwin03',
#  'kwb6675',
#  'robert334',
#  'sdh0321',
#  'young6198',
#  'comkiwer',
#  'hari2080',
#  'lixflora',
#  'rhksdlr134',
#  'semaj10',
#  'tgingod',
#  'wdf_day',
#  'eunsung_lim',
#  'jwelyl',
#  'daemyungmk',
#  'dart',
#  'oh20020409',
#  'yskang',
#  'sini3181',
#  'bysu',
#  'dngnogu',
#  'forget1026',
#  'ioskya',
#  'ktypouoo',
#  'sym2sym',
#  'anzanda',
#  'ch1515',
#  'gyunghoe',
#  'isalpha',
#  '0rch1d',
#  'ctaaone',
#  'sj6188',
#  'skyshr',
#  'william9906',
#  'gjdms611',
#  'qwerpoiu1236',
#  'wasd123',
#  '01jm',
#  'chsong00',
#  'jaimemin',
#  'junah',
#  'mwryan',
#  'qktlf789456',
#  '021gundam',
#  'k550706',
#  'suker80',
#  'jazz4rabbit',
#  'jsovsb22',
#  'minigimbob',
#  'tozangezan',
#  'y_cat',
#  'fallguy1250',
#  'g072923',
#  'jhjjj1224',
#  'kdw9687',
#  'surkitz',
#  'tjdnfls1234',
#  'hssong',
#  'kas123123',
#  'magenta',
#  'taejin1221',
#  'dayo05',
#  'dun04115',
#  'jabbong',
#  'marshal1101',
#  'sunga201',
#  'camo132108',
#  'dankimh',
#  'kysu5095',
#  'blinkingstar',
#  'jnha12345',
#  'rlaxodnd5',
#  'aiden1927',
#  'ktbaek',
#  'qhsl1213',
#  'steve11344',
#  'exupery',
#  'qotmd01',
#  'kaist19',
#  'moonsong98',
#  'starlett',
#  'aza1200',
#  'diadiadl',
#  'jwalag87',
#  'zdsay5863',
#  'horsedrinkscoffee',
#  'khy1234',
#  'knslyr',
#  'yjinpark',
#  'dmsxo',
#  'korabcd',
#  'park780172',
#  'secrett2633',
#  'songibusut',
#  'anima94',
#  'dlwocks1209',
#  'hyoseok',
#  'seojeongwook2',
#  'vire3064',
#  'jiyoz',
#  'lju0912',
#  'psst54',
#  'rlatkddn212',
#  'timbergrizz',
#  'xb205',
#  'convert7342',
#  'dps2',
#  'jin74137',
#  'masterchip',
#  'cbda',
#  'faang12594',
#  'forest14',
#  'ksmzzang2003',
#  'line_jin',
#  'rockwhale83',
#  'sb3991',
#  'seonghoon',
#  'baba1',
#  'greeng00se',
#  'jizon',
#  'sangdo913',
#  'sapple',
#  'tlqckd0',
#  'gh5976',
#  'inseck1121',
#  'kkm0476',
#  'ojhoney92',
#  'wlsdka12',
#  'hyper2012',
#  'lemonoyaa',
#  'sushiroo0',
#  'alpyh217',
#  'qwert087542',
#  'skynet',
#  'aspalt85',
#  'gch99517',
#  'msbmkim',
#  'my0421kr',
#  'myunghonim',
#  'rhgustmd123',
#  'hakgb11',
#  'hgh21233',
#  'okaybody5',
#  'pk661',
#  'wjd30142',
#  'ykmyou',
#  'yousrain',
#  'lstwinsj3',
#  'chowder0018',
#  'gns0187',
#  'leehe228',
#  'otkmrecital',
#  'tmdtjq32',
#  'woohyun_jng',
#  'abcdvd',
#  'ashooozzz',
#  'dezavva',
#  'jaemina',
#  'jasonkoo',
#  'jongseo_park',
#  'joonhee305',
#  'kgr4163',
#  'rlatndh1234',
#  'sefrd',
#  'tajava2006',
#  'zkfzpf56',
#  'n99joon',
#  'swh98',
#  'dajinstory',
#  'qkrdlfrb123',
#  'scalalang',
#  'seungchan0325',
#  'sochun1518',
#  'yhc3006',
#  'conankun',
#  'dn3522',
#  'leejh9226',
#  'n7484443',
#  '13months',
#  'greydra_k',
#  'kth004',
#  'greedy0110',
#  'johoon4687',
#  'junhopark',
#  'k95yong',
#  'mmj9808',
#  'paulsohn',
#  'q9922000',
#  'circlezer0',
#  'crazymi',
#  'leecheomji',
#  'lkmlkm00',
#  'milanoderby',
#  'yunjaekid',
#  'elzendich',
#  'hyeonguk',
#  'kdyfloat',
#  'kravi',
#  'ls123kr',
#  'mk9901',
#  'polohee81',
#  'sungbin95',
#  'taesick',
#  'vect_r',
#  'dbtlwns',
#  'htt0099',
#  'minjea917',
#  'oknkc8',
#  'siyamaki',
#  'tristan3716',
#  'zzapCoder',
#  'chojo1532',
#  'easteregg423',
#  'gyeongmin',
#  'handsks',
#  'nci2002',
#  '31n5ang',
#  'ckj31110',
#  'dwgbjdhks',
#  'god_god',
#  'omh9876',
#  'rlaeogh89',
#  'yoonsang9114',
#  'apple8718',
#  'gbe0808',
#  'hschoi93',
#  'kpqi5858',
#  'mahoon2',
#  'mgkim011',
#  'o98123',
#  'tae',
#  'beawall',
#  'dksu40',
#  'hyunya',
#  'jgs03177',
#  'whisoo98',
#  'ggusg0317',
#  'hyun0404woo',
#  'jmseo1204',
#  'joke',
#  'ljk0411jg',
#  'young_out',
#  'froglike6',
#  'kuman514',
#  'backjun',
#  'df1097',
#  'dmseka0829',
#  'kdi97asd',
#  'plvs_vltra',
#  'rim',
#  'rlaehdwns99',
#  'ch96an',
#  'plenilune',
#  'thoughtman2',
#  'tofhddl9',
#  'bloa1234',
#  'brownmole01',
#  'chlwodyd9829',
#  'gusdn0657',
#  'kimyul528',
#  'mettew0585',
#  'sjw3288',
#  'vsono',
#  'jagajang',
#  'noahahn1214',
#  'sevity',
#  'tlsrudejr123',
#  'vividswan',
#  'zmtn94',
#  'cws0173',
#  'devruby',
#  'doyuneee',
#  'factor3725',
#  'honeysleep',
#  'jf297',
#  'kyun2024',
#  'mantissa',
#  'melonasona',
#  '2cu1001',
#  'ak3243',
#  'alswhd1113',
#  'chan120317',
#  'rldnjs7723',
#  'swrho',
#  'wkd48632',
#  'yj9404',
#  'cyk6545',
#  'hyeseungmoon',
#  'hys3396',
#  'lifedev',
#  'lsc4719',
#  'mame',
#  'noel7781',
#  'persica',
#  'seoo2001',
#  'sosoo',
#  'wanderkind',
#  'ageheight',
#  'cloud7412',
#  'dlehgns011',
#  'dygmm4288',
#  'gyuho965',
#  'tjdahr25',
#  'dlrbduf1346',
#  'greimul',
#  'guswns137',
#  'kevin35kevin',
#  'xfrnk2',
#  '7942jun',
#  'bijou9842',
#  'kangkh0906',
#  'qazxcv6090',
#  'sonjt00',
#  'sustkadl',
#  'lms062111',
#  'mircom2002',
#  'scala0114',
#  'yt7good',
#  '9114jin',
#  'aflat',
#  'ensia96',
#  'fqqwet',
#  'iriszero',
#  'kyujeong',
#  'peisea0830',
#  'aung',
#  'bbangso0322',
#  'doodle0',
#  'jwpee',
#  'mj2park',
#  'seh200',
#  'w8385',
#  'boll0918',
#  'cseteram',
#  'djghdy',
#  'ilovehm95',
#  ...]

# %%
lib_df
# Out:
#          target        user_id  problem_number  user_tier  problem_tier  \
# 0             0  teddybear1024           12920         21            17
# 1             0  teddybear1024           29768         21            11
# 2             1  teddybear1024           29767         21             7
# 3             1  teddybear1024           13511         21            18
# 4             3  teddybear1024           29197         21             9
# ...         ...            ...             ...        ...           ...
# 2604305       0         wwqw58            1427         15             6
# 2604306       0         wwqw58           19941         15             8
# 2604307       0         wwqw58           19939         15             7
# 2604308       0         wwqw58           19940         15            11
# 2604309       1         wwqw58            2941         15             6
#
#                                          problem_algorithm  \
# 0                                  ['다이나믹 프로그래밍', '배낭 문제']
# 1                                ['애드 혹', '해 구성하기', '문자열']
# 2                               ['그리디 알고리즘', '누적 합', '정렬']
# 3                     ['자료 구조', '최소 공통 조상', '희소 배열', '트리']
# 4        ['자료 구조', '유클리드 호제법', '기하학', '해시를 사용한 집합과 맵', ...
# ...                                                    ...
# 2604305                                      ['정렬', '문자열']
# 2604306                                       ['그리디 알고리즘']
# 2604307                                 ['그리디 알고리즘', '수학']
# 2604308  ['너비 우선 탐색', '그래프 이론', '그래프 탐색', '그리디 알고리즘', '...
# 2604309                                      ['구현', '문자열']
#
#          cat_problem_avg_try  \
# 0                          4
# 1                          1
# 2                          2
# 3                          4
# 4                          3
# ...                      ...
# 2604305                    2
# 2604306                    2
# 2604307                    3
# 2604308                    4
# 2604309                    2
#
#                                        user_weak_algorithm
# 0        ['자료 구조', '그래프 이론', '수학', '다이나믹 프로그래밍', '그리디 알...
# 1        ['자료 구조', '그래프 이론', '수학', '다이나믹 프로그래밍', '그리디 알...
# 2        ['자료 구조', '그래프 이론', '수학', '다이나믹 프로그래밍', '그리디 알...
# 3        ['자료 구조', '그래프 이론', '수학', '다이나믹 프로그래밍', '그리디 알...
# 4        ['자료 구조', '그래프 이론', '수학', '다이나믹 프로그래밍', '그리디 알...
# ...                                                    ...
# 2604305  ['그래프 이론', '그래프 탐색', '자료 구조', '너비 우선 탐색', '다이나...
# 2604306  ['그래프 이론', '그래프 탐색', '자료 구조', '너비 우선 탐색', '다이나...
# 2604307  ['그래프 이론', '그래프 탐색', '자료 구조', '너비 우선 탐색', '다이나...
# 2604308  ['그래프 이론', '그래프 탐색', '자료 구조', '너비 우선 탐색', '다이나...
# 2604309  ['그래프 이론', '그래프 탐색', '자료 구조', '너비 우선 탐색', '다이나...
#
# [2604310 rows x 8 columns]

# %%
def get_user_non_problem(user):

   problem_list = problem_df['problem_number']
   u_problem_list = user_df.groupby('user_id')['problem_number'].apply(list).to_dict()[user]
   user_tier = user_df.loc[user_df['user_id'] == user,'user_tier'].iloc[0]
   user_weak_algorithm = lib_df.loc[lib_df['user_id']==user, 'user_weak_algorithm'].iloc[0]
   user_weak_algorithm = ast.literal_eval(user_weak_algorithm)[:5]

   ans = [item for item in problem_list if item not in u_problem_list]

   user_non_problem_df = pd.DataFrame({'user_id': [user]*len(ans), 'problem_number': ans, 'user_tier': [user_tier]*len(ans), 'user_weak_algorithm': [user_weak_algorithm] * len(ans)})
   
   semi_problem_df = problem_df.drop(['problem_name',
      'problem_time_condition', 'problem_memory_condition',
      'problem_submission_count', 'problem_answer_submission_count',
      'problem_answered_people_count', 'problem_correct_rate',
      'problem_avg_try'],axis=1)
   
   user_non_problem_df = user_non_problem_df.merge(semi_problem_df, on = ['problem_number'], how='left')
   
   user_non_problem_df['problem_algorithm'] = user_non_problem_df['problem_algorithm'].apply(ast.literal_eval)

   user_non_problem_df['user_id'] = user_ID_Encoder.transform(user_non_problem_df['user_id'])
   user_non_problem_df['problem_number'] = problem_number_Encoder.transform(user_non_problem_df['problem_number'])
   user_non_problem_df['problem_algorithm'] = user_non_problem_df['problem_algorithm'].apply(lambda x: problem_algorithm_Encoder.transform(x))
   user_non_problem_df['user_weak_algorithm'] = user_non_problem_df['user_weak_algorithm'].apply(lambda x: problem_algorithm_Encoder.transform(x))

   return user_non_problem_df

# %%
user_id_field = 1
user_tier_field = 0.5
problem_number_field = 1
problem_tier_field = 0.5
cat_problem_avg_try_field = 0
problem_algorithm_field = 1
user_weak_algorithm_field = 5

# %%
def create_user_ffm_data(user_name, result_df):
    
    user_libffm_path = '../Dataset/user_libffm_data_folder/'

    with open(os.path.join(user_libffm_path, f'{user_name}_libffm_binary.txt'), 'w') as file:
        for i, v in result_df.iterrows():

            result_string = f"0:{v['user_id']}:{user_id_field} 1:{v['user_tier']}:{user_tier_field} 2:{v['problem_number']}:{problem_number_field} 3:{v['problem_tier']}:{problem_tier_field} 4:{v['cat_problem_avg_try']}:{cat_problem_avg_try_field} "
            
            for num, algorithm_num in enumerate(v['problem_algorithm']):
                result_string += f"5:{algorithm_num}:{(problem_algorithm_field / len(v['problem_algorithm'])):.2f} "
            
            for num, algorithm_num in enumerate(v['user_weak_algorithm']):
                result_string += f"6:{algorithm_num}:{(user_weak_algorithm_field / len(v['user_weak_algorithm']) * (1 - num/10)):.2f} "
            
            file.write(result_string + '\n')

    with open(os.path.join(user_libffm_path, f'{user_name}_libffm_reg.txt'), 'w') as file:
        for i, v in result_df.iterrows():

            result_string = f"0:{v['user_id']}:{user_id_field} 1:{v['user_tier']}:{user_tier_field} 2:{v['problem_number']}:{problem_number_field} 3:{v['problem_tier']}:{problem_tier_field} 4:{v['cat_problem_avg_try']}:{cat_problem_avg_try_field} "
            
            for num, algorithm_num in enumerate(v['problem_algorithm']):
                result_string += f"5:{algorithm_num}:{(problem_algorithm_field / len(v['problem_algorithm'])):.2f} "
            
            for num, algorithm_num in enumerate(v['user_weak_algorithm']):
                result_string += f"6:{algorithm_num}:{(user_weak_algorithm_field / len(v['user_weak_algorithm']) * (1 - num/10)):.2f} "
            
            file.write(result_string + '\n')

# %%
user_name_list = ['vs6641', 'whisoo98', 'cym', 'wwqw58', 'csehydrogen']

for user_name in user_name_list:
    result_df = get_user_non_problem(user_name)
    create_user_ffm_data(user_name, result_df)
